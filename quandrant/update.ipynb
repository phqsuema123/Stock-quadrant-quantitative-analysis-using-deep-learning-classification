# %%
import json
# Open and read the file
with open("C:/Users/Admin/OneDrive/Desktop/Stock-quadrant-quantitative-analysis-using-deep-learning-classification/data collection/get_stcok_name/sets_eod_price.json", "r") as file:
    data = json.load(file)

# Now 'data' is a Python dictionary or list
print(data)
# Out:
# [{'date': '2025-08-08', 'symbol': '1DIV', 'securityType': 'ETF', 'adjustedPriceFlag': 'N', 'prior': 10.64, 'open': 10.65, 'high': 10.71, 'low': 10.65, 'close': 10.7, 'average': 10.696011904761905, 'aomVolume': 16800.0, 'aomValue': 179693.0, 'trVolume': None, 'trValue': None, 'totalVolume': 16859.0, 'totalValue': 180323.8, 'pe': None, 'pbv': 1.11, 'bvps': 9.66, 'dividendYield': 2.3399999141693115, 'marketCap': 1018572279.7, 'volumeTurnover': 0.017710211007620453}, {'date': '2025-08-08', 'symbol': '24CS', 'securityType': 'CS', 'adjustedPriceFlag': 'N', 'prior': 1.29, 'open': 1.29, 'high': 1.36, 'low': 1.26, 'close': 1.35, 'average': 1.3329275059568495, 'aomVolume': 12254800.0, 'aomValue': 16334760.0, 'trVolume': 0.0, 'trValue': 0.0, 'totalVolume': 12254815.0, 'totalValue': 16334780.32, 'pe': None, 'pbv': 2.01, 'bvps': 0.67, 'dividendYield': None, 'marketCap': 654750000.0, 'volumeTurnover': 2.526765979381443}, {'date': '2025-08-08', 'symbol': '24CS-F', 'securityType': 'CSF', 'adjustedPr
# ...

# %%
import pandas as pd

# Read the JSON file into a DataFrame
df = pd.read_json("C:/Users/Admin/OneDrive/Desktop/Stock-quadrant-quantitative-analysis-using-deep-learning-classification/data collection/get_stcok_name/sets_eod_price.json")

# Show first 5 rows
print(df.head())
# Out:
#         date   symbol securityType adjustedPriceFlag  prior   open   high  \
# 0 2025-08-08     1DIV          ETF                 N  10.64  10.65  10.71
# 1 2025-08-08     24CS           CS                 N   1.29   1.29   1.36
# 2 2025-08-08   24CS-F          CSF                 N   3.40    NaN    NaN
# 3 2025-08-08  24CS-W1            W                 N   0.19   0.19   0.24
# 4 2025-08-08  24CS-W2            W                 N   0.30   0.31   0.33
#
#      low  close    average  ...  trVolume  trValue  totalVolume   totalValue  \
# 0  10.65  10.70  10.696012  ...       NaN      NaN        16859    180323.80
# 1   1.26   1.35   1.332928  ...       0.0      0.0     12254815  16334780.32
# 2    NaN    NaN        NaN  ...       NaN      NaN            0         0.00
# 3   0.19   0.22   0.214304  ...       NaN      NaN      3611930    774045.21
# 4   0.30   0.32   0.320355  ...       NaN      NaN      2571980    823939.70
#
# ...

# %%
df.head()  # display the first few rows of the DataFrame
# Out:
#         date   symbol securityType adjustedPriceFlag  prior   open   high  \
# 0 2025-08-08     1DIV          ETF                 N  10.64  10.65  10.71
# 1 2025-08-08     24CS           CS                 N   1.29   1.29   1.36
# 2 2025-08-08   24CS-F          CSF                 N   3.40    NaN    NaN
# 3 2025-08-08  24CS-W1            W                 N   0.19   0.19   0.24
# 4 2025-08-08  24CS-W2            W                 N   0.30   0.31   0.33
#
#      low  close    average  ...  trVolume  trValue  totalVolume   totalValue  \
# 0  10.65  10.70  10.696012  ...       NaN      NaN        16859    180323.80
# 1   1.26   1.35   1.332928  ...       0.0      0.0     12254815  16334780.32
# 2    NaN    NaN        NaN  ...       NaN      NaN            0         0.00
# 3   0.19   0.22   0.214304  ...       NaN      NaN      3611930    774045.21
# 4   0.30   0.32   0.320355  ...       NaN      NaN      2571980    823939.70
#
# ...

# %%
df_financial=pd.DataFrame(columns=['symbol','eps','pe','pbv','market_cap',"dividendYield"])
